# %%
import sys
sys.path.append("../src")

from datahabit import (
    TaskData, DataCleaner, BehaviorAnalyzer,
    DeadlinePredictor, PatternDetector
)

task = TaskData("2025-001", "Assignment 1", "2025-11-04 10:00:00")

cleaner = DataCleaner()
df_clean = cleaner.clean({"score": "90", "time": "2"})

behavior = BehaviorAnalyzer()
behavior.analyze(df_clean)

predictor = DeadlinePredictor()
print(predictor.predict(task))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 12
#       9 task = TaskData("2025-001", "Assignment 1", "2025-11-04 10:00:00")
#      11 cleaner = DataCleaner()
# ---> 12 df_clean = cleaner.clean({"score": "90", "time": "2"})
#      14 behavior = BehaviorAnalyzer()
#      15 behavior.analyze(df_clean)
#
# AttributeError: 'DataCleaner' object has no attribute 'clean'
