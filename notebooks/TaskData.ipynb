# %%
import sys
sys.path.append("..")   # notebook is likely in notebooks/
from DataHabit.task_data import TaskData, TaskDataError

t = TaskData("2025-001", "Assignment 1", "2025-11-04 10:00:00")
print(t)
print("Delay hours:", t.get_delay("2025-11-05 10:00:00"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
#       2 sys.path.append("..")   # notebook is likely in notebooks/
# ----> 3 from DataHabit.task_data import TaskData, TaskDataError
#       5 t = TaskData("2025-001", "Assignment 1", "2025-11-04 10:00:00")
#       6 print(t)
#
# ModuleNotFoundError: No module named 'DataHabit'
